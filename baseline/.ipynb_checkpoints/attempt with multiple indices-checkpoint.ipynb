# %%
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
from statsmodels.tsa.vector_ar.vecm import VECM, select_order, select_coint_rank
from time_series_utils import TSA
import matplotlib.pyplot as plt

# %%
start_date = pd.Timestamp("2000-01-01")
end_date = pd.Timestamp("2019-12-31")

# %%
# "SPY": SPDR S&P 500 ETF Trust
# "IWM": iShares Russell 2000 ETF 
# "QQQ": Invesco QQQ Trust (ETF based on the Nasdaq-100 Index)
# "DIA": SPDR Dow Jones Industrial Average ETF Trust
sp500_df = yf.download("SPY", start=start_date, end=end_date)
russell2000_df = yf.download("IWM", start=start_date, end=end_date)
nasdaq100_df = yf.download("QQQ", start=start_date, end=end_date)
dia_df = yf.download("DIA", start=start_date, end=end_date)

sp500_df.shape[0], russell2000_df.shape[0], nasdaq100_df.shape[0], dia_df.shape[0]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (5030, 4929, 5030, 5030)

# %%
sp500 = sp500_df["Adj Close"]
russell2000 = russell2000_df["Adj Close"]
nasdaq100 = nasdaq100_df["Adj Close"]
dia = dia_df["Adj Close"]
basket_df = pd.concat([sp500, russell2000, nasdaq100, dia], axis=1, join="inner")
basket_df.columns = ["sp500", "russell2000", "nasdaq100", "dia"]
basket_df
# Out:
#                                 sp500  russell2000   nasdaq100         dia
# Date
# 2000-05-26 00:00:00-04:00   90.664688    33.982513   66.853607   62.454620
# 2000-05-30 00:00:00-04:00   93.621094    35.236824   73.571198   63.855137
# 2000-05-31 00:00:00-04:00   93.826454    35.364571   71.475304   63.779469
# 2000-06-01 00:00:00-04:00   95.468918    36.165916   75.129677   64.498558
# 2000-06-02 00:00:00-04:00   97.131943    38.047401   80.503754   65.113701
# ...                               ...          ...         ...         ...
# 2019-12-23 00:00:00-05:00  306.215393   160.106949  208.067749  269.091522
# 2019-12-24 00:00:00-05:00  306.224976   160.472794  208.175812  268.789795
# 2019-12-26 00:00:00-05:00  307.855011   160.472794  210.012756  269.779938
# 2019-12-27 00:00:00-05:00  307.778748   159.683334  209.835938  270.034607
# 2019-12-30 00:00:00-05:00  306.081940   159.278976  208.460693  268.337158
#
# [4929 rows x 4 columns]

# %%
train_df = basket_df.loc[basket_df.index < "2017-01-01"].reset_index(drop=True)
test_df = basket_df.loc[basket_df.index >= "2017-01-01"].reset_index(drop=True)

# %%
train_df.corr()
# Out:
#                 sp500  russell2000  nasdaq100       dia
# sp500        1.000000     0.973716   0.956378  0.989335
# russell2000  0.973716     1.000000   0.893333  0.987343
# nasdaq100    0.956378     0.893333   1.000000  0.927874
# dia          0.989335     0.987343   0.927874  1.000000

# %% [markdown]
# # VECM / VAR

# %% [markdown]
# $$\Delta y_t = \alpha \beta^T y_{t-1} + \Gamma_1 \Delta y_{t-1} + \dots + \Gamma_{p-1} \Delta y_{t-p+1} + u_t$$
# where $\alpha, \beta \in \mathbb{R}^{K \times r}$ and $\Gamma_i \in \mathbb{R}^{K \times K}$ for $i = 1, \dots, p-1$ are the parameters and $u_t$ is $K$-dimensional white noise. Both $\alpha$ and $\beta$ have rank $r$ - then so called cointegration rank.

# %% [markdown]
# ## Choose Deterministic Terms

# %%
deterministic = "colo" # "n", "ci", "co", "li", "lo"

# %% [markdown]
# ## Select Lag Order

# %%
# without `.reset_index(drop=True)`: warning - not use date index
lag_order = select_order(data=train_df, maxlags=10, deterministic=deterministic)
lag_order.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
print(lag_order)
# Out:
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 8, BIC -> 0, FPE -> 8, HQIC ->  2>

# %%
lag_order.aic, lag_order.bic, lag_order.fpe, lag_order.hqic
# Out:
# (8, 0, 8, 2)

# %% [markdown]
# ## Cointegration Rank

# %%
# `det_order=-1`: no deterministic terms
rank_test = select_coint_rank(train_df, det_order=-1, k_ar_diff=lag_order.aic, signif=0.05)
rank_test.rank
# Out:
# 1

# %%
rank_test.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Model

# %%
vecm = VECM(train_df, 
            k_ar_diff=lag_order.aic, 
            coint_rank=rank_test.rank,
            deterministic=deterministic)

# %%
vecm_res = vecm.fit()
vecm_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
# Det. terms outside the coint. relation & lagged endog. parameters for equation sp500
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0689      0.051     -1.355      0.175      -0.169       0.031
# lin_trend       3.709e-05   1.53e-05      2.420      0.016    7.05e-06    6.71e-05
# L1.sp500          -0.1921      0.086     -2.228      0.026      -0.361      -0.023
# L1.russell2000     0.0319      0.045      0.703      0.482      -0.057       0.121
# L1.nasdaq100       0.1249      0.041      3.057      0.002       0.045       0.205
# L1.dia             0.0577      0.081      0.715      0.475      -0.100       0.216
# L2.sp500          -0.2727      0.087     -3.147      0.002      -0.443      -0.103
# L2.russell2000     0.1026      0.045      2.263      0.024       0.014       0.191
# L2.nasdaq100       0.0495      0.041      1.201      0.230      -0.031       0.130
# L2.dia             0.1582      0.081      1.957      0.050      -0.000       0.317
# L3.sp500          -0.1183      0.087     -1.359      0.174      -0.289       0.052
# L3.russell2000     0.0148      0.045      0.326      0.744      -0.074       0.104
# L3.nasdaq100      -0.0202      0.041     -0.487      0.626      -0.101       0.061
# L3.dia             0.1390      0.081      1.716      0.086      -0.020       0.298
# L4.sp500          -0.0586      0.087     -0.676      0.499      -0.229       0.111
# L4.russell2000     0.0339      0.045      0.747      0.455      -0.055       0.123
# L4.nasdaq100      -0.0172      0.041     -0.417      0.677      -0.098       0.064
# L4.dia             0.0244      0.081      0.302      0.763      -0.134       0.183
# L5.sp500          -0.0505      0.087     -0.583      0.560      -0.220       0.119
# L5.russell2000    -0.0513      0.045     -1.135      0.257      -0.140       0.037
# L5.nasdaq100       0.0201      0.041      0.492      0.623      -0.060       0.100
# L5.dia             0.0320      0.081      0.396      0.692      -0.126       0.190
# L6.sp500           0.0497      0.086      0.575      0.565      -0.120       0.219
# L6.russell2000     0.0544      0.045      1.202      0.229      -0.034       0.143
# L6.nasdaq100      -0.0164      0.041     -0.403      0.687      -0.096       0.063
# L6.dia            -0.1136      0.081     -1.410      0.159      -0.272       0.044
# L7.sp500           0.0338      0.086      0.394      0.694      -0.135       0.202
# L7.russell2000    -0.0343      0.045     -0.760      0.447      -0.123       0.054
# L7.nasdaq100       0.0316      0.040      0.782      0.434      -0.048       0.111
# L7.dia            -0.0463      0.081     -0.575      0.565      -0.204       0.112
# L8.sp500          -0.0976      0.085     -1.142      0.254      -0.265       0.070
# L8.russell2000    -0.0088      0.045     -0.194      0.846      -0.097       0.080
# L8.nasdaq100      -0.0341      0.040     -0.859      0.391      -0.112       0.044
# L8.dia             0.1698      0.080      2.115      0.034       0.012       0.327
# Det. terms outside the coint. relation & lagged endog. parameters for equation russell2000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0359      0.038     -0.946      0.344      -0.110       0.038
# lin_trend        1.85e-05   1.14e-05      1.620      0.105   -3.88e-06    4.09e-05
# L1.sp500          -0.1060      0.064     -1.650      0.099      -0.232       0.020
# L1.russell2000    -0.0006      0.034     -0.018      0.986      -0.067       0.066
# L1.nasdaq100       0.0533      0.030      1.752      0.080      -0.006       0.113
# L1.dia             0.0503      0.060      0.836      0.403      -0.068       0.168
# L2.sp500          -0.1022      0.065     -1.582      0.114      -0.229       0.024
# L2.russell2000     0.0367      0.034      1.088      0.277      -0.029       0.103
# L2.nasdaq100       0.0121      0.031      0.393      0.694      -0.048       0.072
# L2.dia             0.0755      0.060      1.253      0.210      -0.043       0.194
# L3.sp500          -0.0245      0.065     -0.378      0.705      -0.152       0.103
# L3.russell2000    -0.0272      0.034     -0.805      0.421      -0.093       0.039
# L3.nasdaq100      -0.0215      0.031     -0.696      0.486      -0.082       0.039
# L3.dia             0.0731      0.060      1.211      0.226      -0.045       0.191
# L4.sp500          -0.1279      0.065     -1.978      0.048      -0.255      -0.001
# L4.russell2000     0.0006      0.034      0.017      0.987      -0.066       0.067
# L4.nasdaq100       0.0312      0.031      1.013      0.311      -0.029       0.091
# L4.dia             0.1083      0.060      1.800      0.072      -0.010       0.226
# L5.sp500          -0.0026      0.064     -0.041      0.967      -0.129       0.124
# L5.russell2000    -0.0425      0.034     -1.261      0.207      -0.109       0.024
# L5.nasdaq100       0.0179      0.030      0.589      0.556      -0.042       0.078
# L5.dia            -0.0111      0.060     -0.185      0.853      -0.129       0.107
# L6.sp500           0.0118      0.064      0.183      0.854      -0.114       0.138
# L6.russell2000     0.0120      0.034      0.355      0.723      -0.054       0.078
# L6.nasdaq100      -0.0305      0.030     -1.006      0.314      -0.090       0.029
# L6.dia            -0.0109      0.060     -0.181      0.856      -0.129       0.107
# L7.sp500          -0.0408      0.064     -0.636      0.525      -0.166       0.085
# L7.russell2000    -0.0243      0.034     -0.724      0.469      -0.090       0.042
# L7.nasdaq100       0.0265      0.030      0.879      0.380      -0.033       0.086
# L7.dia             0.0464      0.060      0.773      0.440      -0.071       0.164
# L8.sp500          -0.0635      0.064     -0.998      0.319      -0.188       0.061
# L8.russell2000     0.0214      0.034      0.637      0.524      -0.044       0.087
# L8.nasdaq100      -0.0393      0.030     -1.325      0.185      -0.097       0.019
# L8.dia             0.1062      0.060      1.776      0.076      -0.011       0.223
# Det. terms outside the coint. relation & lagged endog. parameters for equation nasdaq100
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1573      0.036     -4.401      0.000      -0.227      -0.087
# lin_trend       4.605e-05   1.08e-05      4.277      0.000    2.49e-05    6.72e-05
# L1.sp500           0.0656      0.061      1.083      0.279      -0.053       0.184
# L1.russell2000    -0.0112      0.032     -0.352      0.725      -0.074       0.051
# L1.nasdaq100      -0.0181      0.029     -0.630      0.528      -0.074       0.038
# L1.dia            -0.0893      0.057     -1.576      0.115      -0.200       0.022
# L2.sp500          -0.0086      0.061     -0.142      0.887      -0.128       0.111
# L2.russell2000     0.0393      0.032      1.234      0.217      -0.023       0.102
# L2.nasdaq100      -0.1086      0.029     -3.755      0.000      -0.165      -0.052
# L2.dia             0.0099      0.057      0.175      0.861      -0.101       0.121
# L3.sp500          -0.0101      0.061     -0.165      0.869      -0.130       0.110
# L3.russell2000     0.0308      0.032      0.968      0.333      -0.032       0.093
# L3.nasdaq100      -0.0437      0.029     -1.501      0.133      -0.101       0.013
# L3.dia             0.0069      0.057      0.122      0.903      -0.105       0.118
# L4.sp500          -0.0557      0.061     -0.913      0.361      -0.175       0.064
# L4.russell2000    -0.0008      0.032     -0.024      0.981      -0.063       0.062
# L4.nasdaq100       0.0193      0.029      0.665      0.506      -0.038       0.076
# L4.dia             0.0575      0.057      1.014      0.311      -0.054       0.169
# L5.sp500           0.0110      0.061      0.181      0.856      -0.108       0.130
# L5.russell2000    -0.0259      0.032     -0.814      0.416      -0.088       0.036
# L5.nasdaq100      -0.0382      0.029     -1.329      0.184      -0.094       0.018
# L5.dia             0.0120      0.057      0.212      0.832      -0.099       0.123
# L6.sp500           0.0746      0.061      1.230      0.219      -0.044       0.194
# L6.russell2000     0.0317      0.032      0.999      0.318      -0.031       0.094
# L6.nasdaq100      -0.0167      0.029     -0.585      0.559      -0.073       0.039
# L6.dia            -0.1283      0.057     -2.266      0.023      -0.239      -0.017
# L7.sp500          -0.0018      0.060     -0.029      0.977      -0.120       0.117
# L7.russell2000    -0.0451      0.032     -1.424      0.154      -0.107       0.017
# L7.nasdaq100       0.0291      0.028      1.024      0.306      -0.027       0.085
# L7.dia             0.0248      0.057      0.438      0.661      -0.086       0.136
# L8.sp500          -0.1065      0.060     -1.774      0.076      -0.224       0.011
# L8.russell2000     0.0156      0.032      0.493      0.622      -0.046       0.078
# L8.nasdaq100      -0.0618      0.028     -2.213      0.027      -0.117      -0.007
# L8.dia             0.1608      0.056      2.852      0.004       0.050       0.271
# Det. terms outside the coint. relation & lagged endog. parameters for equation dia
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0117      0.041     -0.283      0.777      -0.093       0.069
# lin_trend       2.208e-05   1.25e-05      1.772      0.076   -2.34e-06    4.65e-05
# L1.sp500          -0.1055      0.070     -1.506      0.132      -0.243       0.032
# L1.russell2000     0.0295      0.037      0.802      0.423      -0.043       0.102
# L1.nasdaq100       0.0697      0.033      2.098      0.036       0.005       0.135
# L1.dia            -0.0001      0.066     -0.002      0.999      -0.129       0.128
# L2.sp500          -0.2094      0.070     -2.973      0.003      -0.347      -0.071
# L2.russell2000     0.0899      0.037      2.442      0.015       0.018       0.162
# L2.nasdaq100       0.0632      0.033      1.889      0.059      -0.002       0.129
# L2.dia             0.1052      0.066      1.601      0.109      -0.024       0.234
# L3.sp500          -0.0775      0.071     -1.094      0.274      -0.216       0.061
# L3.russell2000    -0.0102      0.037     -0.277      0.782      -0.082       0.062
# L3.nasdaq100      -0.0169      0.034     -0.500      0.617      -0.083       0.049
# L3.dia             0.1231      0.066      1.869      0.062      -0.006       0.252
# L4.sp500          -0.0515      0.071     -0.731      0.465      -0.190       0.087
# L4.russell2000     0.0375      0.037      1.017      0.309      -0.035       0.110
# L4.nasdaq100      -0.0091      0.034     -0.271      0.786      -0.075       0.057
# L4.dia             0.0097      0.066      0.148      0.882      -0.119       0.138
# L5.sp500           0.0086      0.070      0.122      0.903      -0.129       0.146
# L5.russell2000    -0.0737      0.037     -2.006      0.045      -0.146      -0.002
# L5.nasdaq100       0.0064      0.033      0.194      0.846      -0.059       0.072
# L5.dia            -0.0015      0.066     -0.023      0.982      -0.130       0.127
# L6.sp500           0.0411      0.070      0.586      0.558      -0.096       0.179
# L6.russell2000     0.0476      0.037      1.295      0.195      -0.024       0.120
# L6.nasdaq100      -0.0079      0.033     -0.239      0.811      -0.073       0.057
# L6.dia            -0.0971      0.066     -1.482      0.138      -0.226       0.031
# L7.sp500           0.0829      0.070      1.186      0.236      -0.054       0.220
# L7.russell2000    -0.0461      0.037     -1.257      0.209      -0.118       0.026
# L7.nasdaq100       0.0147      0.033      0.448      0.654      -0.050       0.079
# L7.dia            -0.0804      0.065     -1.227      0.220      -0.209       0.048
# L8.sp500          -0.0591      0.069     -0.851      0.395      -0.195       0.077
# L8.russell2000    -0.0225      0.037     -0.613      0.540      -0.094       0.049
# L8.nasdaq100      -0.0257      0.032     -0.797      0.426      -0.089       0.038
# L8.dia             0.1352      0.065      2.073      0.038       0.007       0.263
#                Loading coefficients (alpha) for equation sp500
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.0005      0.001      0.674      0.500      -0.001       0.002
#             Loading coefficients (alpha) for equation russell2000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.0004      0.001      0.855      0.392      -0.001       0.001
#              Loading coefficients (alpha) for equation nasdaq100
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.0017      0.000      3.473      0.001       0.001       0.003
#                 Loading coefficients (alpha) for equation dia
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0001      0.001     -0.242      0.809      -0.001       0.001
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2        -1.9022      1.350     -1.409      0.159      -4.549       0.744
# beta.3        -3.1687      0.584     -5.424      0.000      -4.314      -2.024
# beta.4         2.3765      1.291      1.841      0.066      -0.154       4.907
# ==============================================================================
# """

# %% [markdown]
# ## Forecast

# %%
vecm_res.predict(steps=5)
# Out:
# array([[201.35310482, 124.97275755, 113.54240664, 174.44709431],
#        [201.58266053, 125.12488186, 113.80341958, 174.61102993],
#        [201.88182794, 125.20962787, 113.94144945, 174.85806521],
#        [201.92816963, 125.23686433, 113.92830854, 174.89118386],
#        [201.97445986, 125.28717312, 113.98500178, 174.92332352]])

# %%
for text, nd in zip(
    ["forecast", "lower", "upper"], 
    vecm_res.predict(steps=5, alpha=0.05) # 95% confidence level
):
    print(f"{text}:\n{nd}")
# Out:
# forecast:
# [[201.35310482 124.97275755 113.54240664 174.44709431]
#  [201.58266053 125.12488186 113.80341958 174.61102993]
#  [201.88182794 125.20962787 113.94144945 174.85806521]
#  [201.92816963 125.23686433 113.92830854 174.89118386]
#  [201.97445986 125.28717312 113.98500178 174.92332352]]
# lower:
# [[199.10968555 123.30123721 111.9664672  172.62374477]
#  [198.4937807  122.81270875 111.60525361 172.106833  ]
#  [198.19262598 122.40350651 111.33281839 171.85122657]
#  [197.72920177 122.01326985 110.98478672 171.43906229]
#  [197.34047919 121.71386416 110.73526202 171.09659641]]
# upper:
# [[203.59652408 126.64427789 115.11834607 176.27044386]
#  [204.67154036 127.43705497 116.00158555 177.11522686]
#  [205.5710299  128.01574923 116.55008051 177.86490386]
#  [206.12713749 128.46045881 116.87183035 178.34330542]
#  [206.60844053 128.86048209 117.23474155 178.75005063]]
